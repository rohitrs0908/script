# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])

# %%
df.plot.bar()

# %%
df.plot.barh(stacked = True)

# %%
df.plot.hist(alpha = 0.5)

# %%
df.plot.box()

# %%
userspecific = dict(boxes = 'DarkGreen', whiskers = 'DarkOrange', medians = 'DarkBlue', caps = 'Gray')

# %%
df.plot.box(color = userspecific)

# %%
df.plot.area(stacked= False) #When we need to study about the trend

# %%
#Matplotlib Commands
heart = pd.read_csv('C:\\rohit\\simple\\class0404\\clevelanda.csv')

# %%
sns.lineplot(x = heart['age'], y= heart['thalach'])
plt.ylabel('Thalach')
plt.xlabel('Age')
plt.show()

# %%
#Subplotting
plt.figure(1)
plt.subplot(221)
plt.title('Count of heart pat')
sns.countplot(heart['class'])

plt.subplot(222)
sns.distplot(heart['age'])

plt.subplot(223)
sns.scatterplot(heart['age'],heart['thalach'])

plt.subplot(224)
sns.boxplot(x = heart['age'], y = heart['thalach'])

# %%
df = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])

# %%
sns.pairplot(df)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Load the example flights dataset and conver to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax)

# %%
df1 = np.random.randn(100000)

# %%
sns.distplot(df1, hist = False)

# %%
sns.distplot(df1, kde = False)

# %%
heart.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
sns.countplot(x = 'gender', data = heart, hue = 'class')
plt.legend(loc = 'lower right')

# %%
sns.scatterplot(x = 'age', y= 'thalach', data = heart, hue = 'class')
plt.savefig('img.png')

# %%
sns.lmplot(x = 'age', y = 'thalach', data =heart, row = 'gender')

# %%
sns.lmplot(x = 'age', y = 'thalach', data =heart, col = 'gender')

# %%
plt.figure(figsize = (14,14))
plt.subplot(221)
plt.title('Count of heart pat')
sns.countplot(heart['class'])


plt.subplot(222)
plt.title('Distribution of Age')
sns.distplot(heart['age'])

plt.subplot(223)
plt.title('Correlation between')
sns.scatterplot(heart['age'],heart['thalach'])

plt.subplot(224)
plt.title('Outlier Study')
sns.boxplot(x = heart['age'], y = heart['thalach'])
plt.savefig('Dashboard.png')

# %%
#Read Employee data
emp = pd.read_excel('C:\\rohit\\simple\\class0404\\INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls')

# %%
emp.head()
# Out:
#   EmpNumber  Age Gender EducationBackground MaritalStatus    EmpDepartment  \
# 0  E1001000   32   Male           Marketing        Single            Sales
# 1  E1001006   47   Male           Marketing        Single            Sales
# 2  E1001007   40   Male       Life Sciences       Married            Sales
# 3  E1001009   41   Male     Human Resources      Divorced  Human Resources
# 4  E1001010   60   Male           Marketing        Single            Sales
#
#         EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 0  Sales Executive           Travel_Rarely                10
# 1  Sales Executive           Travel_Rarely                14
# 2  Sales Executive       Travel_Frequently                 5
# 3          Manager           Travel_Rarely                10
# 4  Sales Executive           Travel_Rarely                16
#
#    EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 0                  3  ...                            4
# 1                  4  ...                            4
# 2                  4  ...                            3
# 3                  4  ...                            2
# 4                  4  ...                            4
#
#    TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 0                          10                      2                   2
# 1                          20                      2                   3
# 2                          20                      2                   3
# 3                          23                      2                   2
# 4                          10                      1                   3
#
#    ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# 0                            10                             7
# 1                             7                             7
# 2                            18                            13
# 3                            21                             6
# 4                             2                             2
#
#   YearsSinceLastPromotion  YearsWithCurrManager  Attrition  PerformanceRating
# 0                       0                     8         No                  3
# 1                       1                     7         No                  3
# 2                       1                    12         No                  4
# 3                      12                     6         No                  3
# 4                       2                     2         No                  3
#
# [5 rows x 28 columns]

# %%
sns.countplot(x = 'MaritalStatus', data = emp , hue='EmpWorkLifeBalance')
plt.legend(loc = 'lower right')

# %%
#Subplotting
plt.figure(1)
plt.subplot(221)
plt.title('Count of Gender')
sns.countplot(emp['Gender'])

plt.subplot(222)
plt.title('Distplot of age')
sns.distplot(emp['Age'])

plt.subplot(223)
sns.scatterplot(emp['MaritalStatus'],emp['EmpWorkLifeBalance'])

plt.subplot(224)
sns.boxplot(x = emp['MaritalStatus'], y = emp['EmpWorkLifeBalance'])

# %%
sns.scatterplot(x = 'PerformanceRating', y= 'EmpEnvironmentSatisfaction', data = emp, hue = 'EmpRelationshipSatisfaction')

# %%
sns.lineplot(x = emp['PerformanceRating'], y= emp['Age'])
plt.ylabel('Age')
plt.xlabel('PerformanceRating')
plt.show()
